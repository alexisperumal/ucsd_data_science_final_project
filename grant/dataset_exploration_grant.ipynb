# %%
from sklearn import tree
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(os.path.join('..', "arun/Resources/", 'diagnosis-of-covid-19-and-its-clinical-spectrum.csv'))

# %%
df.head()
# Out:
#         patient_id  patient_age_quantile sars_cov_2_exam_result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#   patient_addmited_to_regular_ward_1_yes_0_no  \
# 0                                           f
# 1                                           f
# 2                                           f
# 3                                           f
# 4                                           f
#
#   patient_addmited_to_semi_intensive_unit_1_yes_0_no  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
len(df)
# Out:
# 5644

# %%
def check_NA(df):
    length = len(df)
    columns=df.columns.values.tolist()
    for column in columns:
        #if (df[column].isnull().sum() < 4000):
        sum=df[column].isnull().sum()
        if (sum > (0.9*length)):
            print("Column: ",column, " Total NaN: ",sum)
        
        #name.append(column)
        #count.append(df[column].isnull().sum())
        #sum=df[column].isnull().sum()
        #percent.append((df[column].isnull().sum())/len(df))
        #print("Column: ",column, " Total NaN: ",sum)

# %%
check_NA(df)
# Out:
# Column:  serum_glucose  Total NaN:  5436
# Column:  mycoplasma_pneumoniae  Total NaN:  5644
# Column:  neutrophils  Total NaN:  5131
# Column:  urea  Total NaN:  5247
# Column:  proteina_c_reativa_mg_dl  Total NaN:  5138
# Column:  creatinine  Total NaN:  5220
# Column:  potassium  Total NaN:  5273
# Column:  sodium  Total NaN:  5274
# Column:  alanine_transaminase  Total NaN:  5419
# Column:  aspartate_transaminase  Total NaN:  5418
# Column:  gamma_glutamyltransferase  Total NaN:  5491
# Column:  total_bilirubin  Total NaN:  5462
# Column:  direct_bilirubin  Total NaN:  5462
# Column:  indirect_bilirubin  Total NaN:  5462
# Column:  alkaline_phosphatase  Total NaN:  5500
# Column:  ionized_calcium  Total NaN:  5594
# Column:  strepto_a  Total NaN:  5312
# Column:  magnesium  Total NaN:  5604
# Column:  pco2_venous_blood_gas_analysis  Total NaN:  5508
# Column:  hb_saturation_venous_blood_gas_analysis  Total NaN:  5508
# ...

# %%
target = df['sars_cov_2_exam_result']

# %%
data = df.drop(['sars_cov_2_exam_result','patient_id', ''], axis=1)
feature_names = data.columns
data.head()
# Out:
#    patient_age_quantile patient_addmited_to_regular_ward_1_yes_0_no  \
# 0                    13                                           f
# 1                    17                                           f
# 2                     8                                           f
# 3                     5                                           f
# 4                    15                                           f
#
#   patient_addmited_to_semi_intensive_unit_1_yes_0_no  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# 4                                                  f
#
#   patient_addmited_to_intensive_care_unit_1_yes_0_no  hematocrit  hemoglobin  \
# 0                                                  f         NaN         NaN
# 1                                                  f    0.236515    -0.02234
# ...

# %%
data.columns
# Out:
# Index(['patient_age_quantile', 'patient_addmited_to_regular_ward_1_yes_0_no',
#        'patient_addmited_to_semi_intensive_unit_1_yes_0_no',
#        'patient_addmited_to_intensive_care_unit_1_yes_0_no', 'hematocrit',
#        'hemoglobin', 'platelets', 'mean_platelet_volume', 'red_blood_cells',
#        'lymphocytes',
#        ...
#        'hb_saturation_arterial_blood_gases',
#        'pco2_arterial_blood_gas_analysis',
#        'base_excess_arterial_blood_gas_analysis',
#        'ph_arterial_blood_gas_analysis',
#        'total_co2_arterial_blood_gas_analysis',
#        'hco3_arterial_blood_gas_analysis', 'po2_arterial_blood_gas_analysis',
#        'arteiral_fio2', 'phosphor', 'cto2_arterial_blood_gas_analysis'],
#       dtype='object', length=109)

# %%
df1 = data.describe(include = 'all')


df1.loc['dtype'] = data.dtypes
df1.loc['size'] = len(data)
df1.loc['% count'] = data.isnull().mean()

# %%
df1
# Out:
#         patient_age_quantile patient_addmited_to_regular_ward_1_yes_0_no  \
# count                   5644                                        5644
# unique                   NaN                                           2
# top                      NaN                                           f
# freq                     NaN                                        5565
# mean                 9.31839                                         NaN
# std                   5.7779                                         NaN
# min                        0                                         NaN
# 25%                        4                                         NaN
# 50%                        9                                         NaN
# 75%                       14                                         NaN
# max                       19                                         NaN
# dtype                  int64                                      object
# ...

# %%
data['patient_addmited_to_regular_ward_1_yes_0_no'].value_counts()
# Out:
# f    5565
# t      79
# Name: patient_addmited_to_regular_ward_1_yes_0_no, dtype: int64

# %%
data['patient_addmited_to_semi_intensive_unit_1_yes_0_no'].value_counts()
# Out:
# f    5594
# t      50
# Name: patient_addmited_to_semi_intensive_unit_1_yes_0_no, dtype: int64

# %%
data['patient_addmited_to_intensive_care_unit_1_yes_0_no'].value_counts()
# Out:
# f    5603
# t      41
# Name: patient_addmited_to_intensive_care_unit_1_yes_0_no, dtype: int64

# %%
df[df['patient_addmited_to_semi_intensive_unit_1_yes_0_no']=='t']
# Out:
#            patient_id  patient_age_quantile sars_cov_2_exam_result  \
# 8     8bb9d64f0215244                     1               negative
# 55    ac357896cbf35fc                    19               negative
# 86    ecaa8e290af8461                    19               negative
# 543   1f9ef4c4c5cc30f                    18               negative
# 671   0f2c3bd3954f19e                     7               negative
# 928   dad2eecc9a0bf16                    19               negative
# 1039  b64bc1acd95fd62                    19               negative
# 1179  9bd1c8c67b6cb11                    19               negative
# 2126  aefa3304cbace4c                    13               negative
# 2144  eb0e780a17f68c2                    19               negative
# 3001  8331bc73200633e                    13               negative
# 3598  d88bc973d6012be                    18               negative
# 3676  14fbe519ce6d40e                    19               negative
# ...

# %%
target.value_counts()
# Out:
# negative    5086
# positive     558
# Name: sars_cov_2_exam_result, dtype: int64

# %%
df[df['patient_addmited_to_intensive_care_unit_1_yes_0_no']=='t']
# Out:
#            patient_id  patient_age_quantile sars_cov_2_exam_result  \
# 110   a4b2116e0689f54                     0               negative
# 152   ecef5dfca43aa2e                     1               negative
# 412   8733b5587ba412f                    19               negative
# 430   3a4c7aa4bed2c6a                     0               negative
# 865   5c50590b1103c00                     1               negative
# 1468  ecd3203a3d14f9b                     0               negative
# 1845  4475e8fd314a180                     1               negative
# 1966  66342a96fc1f90b                    14               positive
# 3180  3def6ac10295169                    18               negative
# 3818  e453b3d4bd51d0d                    19               positive
# 4525  24d381dd4d4447d                     0               negative
# 4636  33bbe2fb8df7a5b                     0               negative
# 4639  6a8d40ea05031e8                    18               negative
# ...
